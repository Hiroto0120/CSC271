# %% [markdown]
# ## CSC271: AI Tool Usage Disclosure -- Project
#
# In the markdown cells below, please answer the following questions about your AI Tool usage for the project.
#
# <div class="alert alert-block alert-success">
# 1. Which AI tools did you use? (e.g., ChatGPT, Github Copilot, Microsoft Copilot, etc.)
# <br><br>
# <i>(If you did not use AI tools, you can answer "None" and skip the rest of the questions, but need to submit the document.)</i>
# </div>

# %% [markdown]
# TODO
# - Microsoft Copilot

# %% [markdown]
# <div class="alert alert-block alert-success">
# 2. What did you ask? (copy/paste key prompts or summarize with bullet points):
# </div>

# %% [markdown]
# TODO
# - I want to visualize xxx, can you write a code using matploylib.pyplot?
# - I got xxx errors, can you help me out solving this issue?
# - Can you make a dict to convert education level (string) into education level (numeric) so that I can merge them later? (edu_to_numeric in project.py)

# %% [markdown]
# <div class="alert alert-block alert-success">
# 3. What AI output did you use in your assignment submission? How much did you edit it and why?
# </div>

# %% [markdown]
# TODO
# - Project.ipynb: [lines 9-12], adapted 〜60%. Asked for codes of visualization (small details)
# - Project.ipynb, Project.py: adpted 〜20%. I got several errors but I was able to solve them by myself exept one Syntax Errors which I asked Copilot.
# - Project.py: [lines 10-16], adapted 〜80%. Asked to make a dict (e.g. "High School": 1, "Associate's Degree": 2, "Associate's": 2...)

# %% [markdown]
# <div class="alert alert-block alert-success">
# 4. How did you verify the output produced?
# </div>

# %% [markdown]
# For the visualization, I verified by checking if the result I got make sense. For example, if the payment of what PhD graduate receive is lower than what high school graduate receive, then there might be higher chance that there is a problem. So I checked all factors if they make sense in the real workd and common sense. For the errors, I also checked stack overflow and was able to see the similar solution and the code worked without any issue. For the dictionary, I check using .unique() function to see if those are really the only variables in education level. I got a result of numbers between 1-5 so what Micrsofot Copilot gave was a correct dict.

# %% [markdown]
# <div class="alert alert-block alert-success">
# 5. <b>Reflection.</b> What did the AI help with? What did you learn? Did you observe any limitations or risks?
# </div>

# %% [markdown]
# AI helped me doing small details and solving errors. Making dictionary is not difficult but takes a bit of time but using AI takes less than 5 seconds. Visualization also has a lot of small details that I need to write such as font-size, color, etc but with AI, it generates faster. Moreover, when I get errors, I usually think about it by myself for a few minutes but if I still cannot solve, then I asked what would be the main issue. However, I learned that AI is not good for interpretation. I once put my visualizatio to AI but the numbers I got were wrong and its interpretation did not make sense to me. This also connects to the limitation part but I think AI is very good for doing small things but should not be the main part of analyzation. Also, I learned that it is crucial to check if what I got is correct and make sense.
