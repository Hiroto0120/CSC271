# %% [markdown]
# ## CSC271: AI Tool Usage Disclosure -- Assignment 1
#
# In the markdown cells below, please answer the following questions about your AI Tool usage for Assignment 1.
#
# <div class="alert alert-block alert-success">
# 1. Which AI tools did you use? (e.g., ChatGPT, Github Copilot, Microsoft Copilot, etc.)
# <br><br>
# <i>(If you did not use AI tools, you can answer "None" and skip the rest of the questions, but need to submit the document.)</i>
# </div>

# %% [markdown]
# TODO
# - Microsoft Copilot

# %% [markdown]
# <div class="alert alert-block alert-success">
# 2. What did you ask? (copy/paste key prompts or summarize with bullet points):
# </div>

# %% [markdown]
# TODO
# - I tried pl = df['Port of Entry'].str.split('-') but I got an AttributeError: 'list' object has no attribute 'str' and I was told that I better check with help() function
# - Check the length for docstrings

# %% [markdown]
# <div class="alert alert-block alert-success">
# 3. What AI output did you use in your assignment submission? How much did you edit it and why?
# </div>

# %% [markdown]
# TODO
# - Snippet A: [lines 53], adapted ~5%. put expand = True
# - Snippet B [line 131]: ~10%, I was told that this docstring is too long (it contained all names of parameters which I do not need to explain here) so I made it shorter

# %% [markdown]
# <div class="alert alert-block alert-success">
# 4. How did you verify the output produced?
# </div>

# %% [markdown]
# I used Automated Testing to see if my code actually runs regardelss of the correctness.
# Also, even though ai_functions is in .py, I like to check each line so I created a new ipynb file and checked each of them by actually assigning real variables and see they return correctly

# %% [markdown]
# <div class="alert alert-block alert-success">
# 5. <b>Reflection.</b> What did the AI help with? What did you learn? Did you observe any limitations or risks?
# </div>

# %% [markdown]
# It helped me to not only to solve a problemm (even a small one) but also helped me to improve how I write a code and what I should do when I get an error. I actually have never used help() function before as I usually go to stack overflow website to find an answer but AI recommeded first use help() function to get a hint about why I am getting an error and what are the ways I can solve this problem and that was faster and learned a lot of things about the function. The risk is that students who are heavily using AI might be able to submit their assignment but without understanding what they submitted. For me, as I mentioned earlier, because of the suggestion by the AI that I better look at help() function, I was able to find that it has expand = True option and I was able to understand what does it do but when the assignment is getting harder and longer, there is definitely a risk where some people mistakely think that they understood everything and when they actually write it, they realize that they actually did not understand. So even when students get help by AI, they always shold understand what that suggestion mean, where is the difference between what students wrote originally and what AI suggested, and most importantly, they do not make a similar mistake or error next time as much as possible.
