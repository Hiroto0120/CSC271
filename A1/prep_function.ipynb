# %%
import pandas as pd
import numpy as np

df = pd.read_csv('traveller-report-daily.csv')
df.head()
# Out:
#          Date                              Port of Entry           Region  \
# 0  2018-01-01                             2060 - Moncton  Atlantic Region
# 1  2018-01-01                2110 - St. Stephen: Traffic  Atlantic Region
# 2  2018-01-01             2114 - St. Stephen: 3rd Bridge  Atlantic Region
# 3  2018-01-01  2115 - St. Stephen: 3rd Bridge Commercial  Atlantic Region
# 4  2018-01-01                  2120 - Woodstock: Traffic  Atlantic Region
#
#    Mode  Sum of Volume
# 0   Air          119.0
# 1  Land          843.0
# 2  Land          364.0
# 3  Land           37.0
# 4  Land          868.0

# %% [markdown]
# # Task 1

# %% [markdown]
# ## clean_volume

# %%
df.rename(columns = {'Sum of Volume' : 'VOLUME'}, inplace = True)
df['VOLUME'] = df['VOLUME'].astype('Int64')
df.head()
# Out:
#          Date                              Port of Entry           Region  \
# 0  2018-01-01                             2060 - Moncton  Atlantic Region
# 1  2018-01-01                2110 - St. Stephen: Traffic  Atlantic Region
# 2  2018-01-01             2114 - St. Stephen: 3rd Bridge  Atlantic Region
# 3  2018-01-01  2115 - St. Stephen: 3rd Bridge Commercial  Atlantic Region
# 4  2018-01-01                  2120 - Woodstock: Traffic  Atlantic Region
#
#    Mode  VOLUME
# 0   Air     119
# 1  Land     843
# 2  Land     364
# 3  Land      37
# 4  Land     868

# %% [markdown]
# ## clean_region

# %%
df['Region'] = df['Region'].replace({'QuÈbec Region': 'Québec Region','Quebec Region': 'Québec Region'})
df['Region'] = df['Region'].str.replace('Region','')

# %% [markdown]
# ## clean_port

# %%
# AI: Debugging, 
# At first, I tried pl = df['Port of Entry'].str.split('-')
# But I got an error: AttributeError: 'list' object has no attribute 'str'
# so I asked AI for debugging and realized that I need expand = True

spl = df['Port of Entry'].str.split('-', expand=True)
df['PORT_ID'] = spl[0].str.strip().astype(int)
df['PORT_NAME'] = spl[1].str.strip()
df = df.drop(columns = 'Port of Entry')

# %% [markdown]
# ## clean_data

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# ## fill_missing_volumes

# %%
df_copy = df.copy()

# %%
df_copy.isnull().sum()
# Out:
# Date              0
# Region            0
# Mode              0
# VOLUME       145794
# PORT_ID           0
# PORT_NAME         0
# dtype: int64

# %%
def fill_missing_volumes(df: pd.DataFrame, strategy: str) -> None:
    """ Modify df by filling missing values in the VOLUME column using the specified strategy. """
    if strategy == 'MEAN':
        df['VOLUME'].fillna(df['VOLUME'].mean())
    elif strategy == 'MEDIAN':
        df['VOLUME'].fillna(df['VOLUME'].median())
    else:
        df['VOLUME'].fillna(0)

# %%
fill_missing_volumes(df, 'MEAN')

# %%
df.isnull().sum()
# Out:
# Date         0
# Region       0
# Mode         0
# VOLUME       0
# PORT_ID      0
# PORT_NAME    0
# dtype: int64

# %% [markdown]
# # Task 2

# %% [markdown]
# ## filter_with_volume

# %%
fil = (df['Region'] == 'Québec') & (df['VOLUME'] >= 100)
result = df[fil]
result
# Out:
# Empty DataFrame
# Columns: [Date, Region, Mode, VOLUME, PORT_ID, PORT_NAME]
# Index: []

# %% [markdown]
# ## find_port_name

# %%
row = df[df['PORT_ID'] == 2060]
row['PORT_NAME'][0]
# Out:
# 'Moncton'

# %% [markdown]
# ## get_mean_volume_by

# %%
result = df.groupby('Region')['VOLUME'].mean()
result
# Out:
# Region
# Atlantic                  419.293232
# Greater Toronto Area     3317.243461
# Northern Ontario          811.334589
# Pacific                  1106.541528
# Prairie                   464.312154
# Québec                     782.17457
# Southern Ontario         2190.017605
# Name: VOLUME, dtype: Float64

# %% [markdown]
# ## get_top_n_by_volume

# %%
total = df.groupby('Region')['VOLUME'].sum()
sort = total.sort_values(ascending = False)
sort.head(3)
# Out:
# Region
# Pacific                  162923855
# Southern Ontario         159225230
# Greater Toronto Area     106918074
# Name: VOLUME, dtype: Int64

# %% [markdown]
# ## compute_volume_by_time

# %%
year = df['Date'].dt.year
month = df['Date'].dt.month

f1 = (df[df['Date'].dt.year == 2023]) & (df[df['Date'].dt.month == 1])
result = f1.groupby('Region')['VOLUME'].sum()
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 4
#       1 year = df['Date'].dt.year
#       2 month = df['Date'].dt.month
# ----> 4 f1 = (df[df['Date'].dt.year == 2023]) & (df[df['Date'].dt.month == 1])
#       5 result = f1.groupby('Region')['VOLUME'].sum()
#       6 result
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/arraylike.py:70, in OpsMixin.__and__(self, other)
#      68 @unpack_zerodim_and_defer("__and__")
#      69 def __and__(self, other):
# ---> 70     return self._logical_method(other, operator.and_)
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:7935, in DataFrame._arith_method(self, other, op)
#    7932 self, other = self._align_for_op(other, axis, flex=True, level=None)
#    7934 with np.errstate(all="ignore"):
# -> 7935     new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7936 return self._construct_result(new_data)
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/frame.py:7978, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7972     assert self.columns.equals(right.columns)
#    7973     # TODO: The previous assertion `assert right._indexed_same(self)`
#    7974     #  fails in cases with empty columns reached via
#    7975     #  _frame_arith_method_with_reindex
#    7976
#    7977     # TODO operate_blockwise expects a manager of the same type
# -> 7978     bm = self._mgr.operate_blockwise(
#    7979         # error: Argument 1 to "operate_blockwise" of "ArrayManager" has
#    7980         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7981         # "ArrayManager"
#    7982         # error: Argument 1 to "operate_blockwise" of "BlockManager" has
#    7983         # incompatible type "Union[ArrayManager, BlockManager]"; expected
#    7984         # "BlockManager"
#    7985         right._mgr,  # type: ignore[arg-type]
#    7986         array_op,
#    7987     )
#    7988     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7990 elif isinstance(right, Series) and axis == 1:
#    7991     # axis=1 means we want to operate row-by-row
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/internals/managers.py:1530, in BlockManager.operate_blockwise(self, other, array_op)
#    1526 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1527     """
#    1528     Apply array_op blockwise with another (aligned) BlockManager.
#    1529     """
# -> 1530     return operate_blockwise(self, other, array_op)
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/internals/ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File /opt/miniconda3/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:442, in logical_op(left, right, op)
#     438 rvalues = right
#     440 if should_extension_dispatch(lvalues, rvalues):
#     441     # Call the method on lvalues
# --> 442     res_values = op(lvalues, rvalues)
#     444 else:
#     445     if isinstance(rvalues, np.ndarray):
#
# TypeError: unsupported operand type(s) for &: 'DatetimeArray' and 'DatetimeArray'

# %% [markdown]
# ## calculate_volume_change

# %%
df.head()
# Out:
#         Date     Region  Mode  VOLUME  PORT_ID  \
# 0 2018-01-01  Atlantic    Air     119     2060
# 1 2018-01-01  Atlantic   Land     843     2110
# 2 2018-01-01  Atlantic   Land     364     2114
# 3 2018-01-01  Atlantic   Land      37     2115
# 4 2018-01-01  Atlantic   Land     868     2120
#
#                             PORT_NAME
# 0                             Moncton
# 1                St. Stephen: Traffic
# 2             St. Stephen: 3rd Bridge
# 3  St. Stephen: 3rd Bridge Commercial
# 4                  Woodstock: Traffic
